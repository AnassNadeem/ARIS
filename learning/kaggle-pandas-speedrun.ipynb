# %% [markdown]
# # Kaggle Pandas micro-course — speedrun
#
# Source: https://www.kaggle.com/learn/pandas — 6 lessons.
#
# **Rules (per Wk 2 Day 1 Block 4):**
# - Skip slide intros, jump to exercises.
# - Copy answers in. If a concept was already used in `notebooks/03-pandas-deep-dive.ipynb`, mark `# already knew this` and move on.
# - Goal: find *gaps*, not pad hours. Commit even partial — evidence you went through it.
#
# **Concepts to confirm cold:** `.agg()` with multi-column dict · `.rename(columns={})` · `.value_counts()` · `.idxmax()` · `pd.to_datetime` · `.dt` accessor · `Series.map()` vs `DataFrame.apply()`.

# %%
import numpy as np
import pandas as pd
print("pandas", pd.__version__)

# %% [markdown]
# ## L1 — Creating, Reading and Writing

# %%
# TODO

# %% [markdown]
# ## L2 — Indexing, Selecting & Assigning

# %%
# TODO

# %% [markdown]
# ## L3 — Summary Functions and Maps

# %%
# TODO

# %% [markdown]
# ## L4 — Grouping and Sorting

# %%
# TODO

# %% [markdown]
# ## L5 — Data Types and Missing Values

# %%
# TODO

# %% [markdown]
# ## L6 — Renaming and Combining

# %%
# TODO

# %% [markdown]
# ## Gaps found
#
# - _
# - _
# - _
